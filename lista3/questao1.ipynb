# %% [markdown]
# # Questão 1
#
# Considere o dados apresentados na tabela abaixo. Obtenha os centroides dos clusters
# utilizando uma rede neural competitiva que corresponde ao algoritmo K-means ,. No
# processo de inicialização considere os itens (a) e (b) abaixo.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style as stl
stl.use('default')
from sklearn.cluster import KMeans
#from minisom import MiniSom

from sklearn.datasets import make_blobs
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.patches import RegularPolygon
from matplotlib import cm, colorbar
from matplotlib.lines import Line2D

# %%
# Colocando os dados da tabela dentro do código
x1 = [-5.82, -4.68, 3.36, 7.72, -7.64, -6.87, 4.47, 7.73, -7.71, -5.91, 2.18, 6.72, -5.25, -6.94, 7.09, 6.81, -4.19, -5.38, 5.08, 7.27]
x2 = [-4.58, 2.16, -3.19, 0.88, 3.06, 0.57, -2.62, -2.01, 3.34, -0.49, 3.81, -0.93, -0.26, -1.22, 0.20, 3.17, 4.24, -1.74, 3.30, 0.93]
x3 = [-1.97, 3.71, 1.09, 1.80, 3.50, -5.45, 5.76, 5.18, -6.33, -5.68, 5.82, -3.04, 0.56, 1.13, 2.25, -4.15, 4.04, 1.43, 5.33, -2.78]

# montando o dataframe
df = pd.DataFrame({'x1': x1, 'x2': x2, 'x3': x3})

# %% [markdown]
# ## a)
# Considere que a rede possui três neurônio que corresponde a existência de três clusters
# nos dados. Inicialize os pesos dos neurônios (centroides) de forma aleatória

# %%
# intanciando o modelo k means
kmeans = KMeans(init='random', n_clusters=3, random_state=0, max_iter=1000)
# fit the model
kmeans.fit(df)
# Out:
# KMeans(init='random', max_iter=1000, n_clusters=3, random_state=0)

# %%
# get the labels
labels = kmeans.labels_

# plot the data hilighting the centroids
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')

ax.scatter(x1, x2, x3, c=labels, s=80)
ax.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], kmeans.cluster_centers_[:, 2], c='green', s=200, marker='*')
plt.title('Distribuição dos dados com suas centroids')
ax.set_xlabel('$X_1$', fontsize=16)
ax.set_ylabel('$X_2$', fontsize=16)
ax.set_zlabel('$X_3$', fontsize=16)
plt.show()

# %% [markdown]
# ## b)
# Considere que existam três clusters e a inicialização dos centros seja dada por
# m1=(0,0,0)^t
# , m2=(1,1,1)^t
# , m3=(-1,0,2)^t

# %%
# inicialize the model with the centroids in m1, m2 and m3
m1 = [[0],[0],[0]]
m2 = [[1],[1],[1]]
m3 = [[-1],[0],[2]]

init = np.concatenate((m1, m2, m3), axis=1)
init
# Out:
# array([[ 0,  1, -1],
#        [ 0,  1,  0],
#        [ 0,  1,  2]])

# %%
# instantiate the model
kmeans = KMeans(init=init, n_clusters=3, random_state=0, max_iter=1000)

# fit the model
kmeans.fit(df)
# Out:
# c:\Users\efrai\Documents\Academico\PDS\venv\lib\site-packages\sklearn\cluster\_kmeans.py:1146: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# KMeans(init=array([[ 0,  1, -1],
#        [ 0,  1,  0],
#        [ 0,  1,  2]]),
#        max_iter=1000, n_clusters=3, random_state=0)

# %%
# get the labels
labels = kmeans.labels_

# plot the data hilighting the centroids
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')

ax.scatter(x1, x2, x3, c=labels, s=80)
ax.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], kmeans.cluster_centers_[:, 2], c='red', s=200, marker='*')
plt.title('Data Distribution with the centroids', pad=20, size=20)
ax.set_xlabel('$X_1$', fontsize=16)
ax.set_ylabel('$X_2$', fontsize=16)
ax.set_zlabel('$X_3$', fontsize=16)
plt.show()
